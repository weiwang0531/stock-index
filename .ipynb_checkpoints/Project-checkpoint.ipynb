# %%
import sys
import csv
import json
import requests
import requests_cache
import numpy as np
import pandas as pd
from yahoo_finance import Share
from pprint import pprint 
from datetime import datetime
import matplotlib.pyplot as plt

import matplotlib as mpl
# %matplotlib inline

import seaborn as sns
sns.set_style('white', {"xtick.major.size": 2, "ytick.major.size": 2})
flatui = ["#9b59b6", "#3498db", "#95a5a6", "#e74c3c", "#34495e", "#2ecc71","#f4cae4"]
sns.set_palette(sns.color_palette(flatui,7))

import missingno as msno

# %%
requests_cache.install_cache('cache')

# %%
comp = Share('AAPL')
c = comp.get_historical('2000-11-03', '2001-01-28')
c[1]["Date"]

# %%
def price(length, ticker):
    date=[]
    price=[]
    report = []
    
    comp = Share(ticker)
    try:
        c = comp.get_historical('2006-01-01', '2016-12-31')
        for i in range(0,length):    # (length) USED TO BE 40
            date.append(pd.to_datetime(c[i]["Date"]))
            price.append(float(c[i]["High"]))
            datef = pd.DataFrame(date)
            pricef = pd.DataFrame(price)
            table1 = pd.concat([datef,pricef],axis = 1)
            table1.columns = ['Date', ticker]
            table1 = table1.set_index("Date")
            
    except Exception:
        table1 = pd.DataFrame()
    
    return table1

# %%
# Yahoo! YQL API
PUBLIC_API_URL = 'https://query.yahooapis.com/v1/public/yql'
OAUTH_API_URL = 'https://query.yahooapis.com/v1/yql'
DATATABLES_URL = 'store://datatables.org/alltableswithkeys'

def myreq(ticker, start, end):
    '''
    input ticker & dates as strings form 'YYYY-MM-DD'
    '''
    params = {'format':'json',
             'env':DATATABLES_URL}
    query = 'select * from yahoo.finance.historicaldata where symbol = "{}" and startDate = "{}" and endDate = "{}"'.format(ticker,start, end)
    params.update({'q':query})
    req = requests.get(PUBLIC_API_URL, params=params)
    req.raise_for_status()
    req = req.json()
    if req['query']['count'] > 0:
        result = req['query']['results']['quote']
        return result
    else:
        pass

# %%
def price1(length, ticker):
    date=[]
    price=[]
    report = []
    
    c = myreq(ticker,'2006-01-01','2006-12-31')
    try:
        for i in range(0,length):    # (length) USED TO BE 40
            date.append(pd.to_datetime(c[i]["Date"]))
            price.append(float(c[i]["High"]))
            datef = pd.DataFrame(date)
            pricef = pd.DataFrame(price)
            table1 = pd.concat([datef,pricef],axis = 1)
            table1.columns = ['Date', ticker]
            table1 = table1.set_index("Date")
            
    except Exception:
        table1 = pd.DataFrame()
    
    return table1

# %%
def price(length, ticker):
    date=[]
    price=[]
    report = []
    
    comp = Share(ticker)
    try:
        c = comp.get_historical('2006-01-01', '2016-12-31')
        for i in range(0,length):    # (length) USED TO BE 40
            date.append(pd.to_datetime(c[i]["Date"]))
            price.append(float(c[i]["High"]))
            datef = pd.DataFrame(date)
            pricef = pd.DataFrame(price)
            table1 = pd.concat([datef,pricef],axis = 1)
            table1.columns = ['Date', ticker]
            table1 = table1.set_index("Date")
            
    except Exception:
        table1 = pd.DataFrame()
    
    return table1

# %%
csv = pd.read_csv('./companylist.csv')
# We want to keep "Finance, Health Care, Technology, Energy"
newcsv = csv[csv["Sector"].isin(["Finance", "Energy","Health Care","Technology"])].reset_index()
del newcsv["index"]

# %%
# Testing with first 40 symbols in the list:
audrey_list = newcsv['Symbol'][0:39]

# %%
# The following creates the "main" DF...

del df #don't run this line if the following loop hasn't been run yet.
for l in audrey_list:
    get = price1(100,l)
    try:
        df = pd.concat([df,get],axis = 1)    # concat. by column 
    except NameError:
        df = pd.DataFrame(get)    # initialize automatically

# %%
# SAVE THE RESULT LOCALLY:
df.to_pickle('cached_df.pkl')

# load it back using:
#df = pd.read_pickle('cached_df.pkl')

# %%
df
# Out:
#                  FCCY       SRCE       JOBS  ABEO       ABMD  AXAS  ACHC  \
# Date
# 2006-12-29  19.970001  32.619999  17.309999  2.80  14.730000  3.24  3.18
# 2006-12-28  19.370003  32.590000  17.240000  2.80  14.890000  3.28  3.12
# 2006-12-27  19.049999  32.500000  17.240000  2.85  14.300000  3.24  3.01
# 2006-12-26  19.270009  31.770000  17.250000  2.85  13.980000  3.32  2.85
# 2006-12-22  19.839992  31.100000  16.610001  2.85  14.130000  3.32  2.98
# 2006-12-21  19.010004  31.549999  16.709999  2.88  15.090000  3.47  2.98
# 2006-12-20  19.010004  31.000000  16.840000  2.90  13.610000  3.62  2.91
# 2006-12-19  19.010004  30.930000  16.959999  2.99  13.660000  3.58  2.50
# 2006-12-18  19.010004  31.740000  16.600000  2.94  13.630000  3.59  2.60
# 2006-12-15  19.079999  31.740000  16.290001  3.00  13.210000  3.70  2.28
# 2006-12-14  19.249990  31.610001  16.670000  3.00  13.250000  3.80  2.29
# 2006-12-13  18.999994  31.270000  16.950001  2.90  13.210000  3.78  2.22
# 2006-12-12  19.149994  31.209999  17.680000  2.20  13.430000  3.90  2.19
# 2006-12-11  19.149994  31.180000  17.780001  2.20  13.410000  3.98  2.21
# 2006-12-08  19.149994  31.209999  17.920000  2.20  13.530000  4.05  2.16
# 2006-12-07  19.249990  31.690001  18.459999  1.80  13.040000  4.13  2.20
# 2006-12-06  18.880009  31.610001  18.440001  1.85  13.230000  4.15  2.20
# 2006-12-05  18.730010  32.200001  17.700001  1.60  13.130000  4.05  2.20
# 2006-12-04  18.990000  31.670000  17.879999  1.55  12.740000  4.10  2.22
# 2006-12-01  18.949991  31.160000  17.799999  1.60  12.990000  4.26  2.22
# 2006-11-30  18.999994  31.389999  17.830000  1.65  12.700000  4.35  2.25
# 2006-11-29  18.999994  31.750000  17.500000  1.60  12.550000  4.22  2.10
# 2006-11-28  18.150002  31.520000  16.900000  1.85  12.410000  3.89  2.16
# 2006-11-27  18.230007  33.169998  17.700001  1.51  12.820000  3.77  2.23
# 2006-11-24  18.499991  33.169998  17.530001  1.35  12.810000  3.72  2.25
# 2006-11-22  18.609996  33.459999  17.450001  1.35  12.840000  3.62  2.20
# 2006-11-21  18.759996  33.389999  17.070000  1.35  13.000000  3.62  2.22
# 2006-11-20  19.340004  33.200001  16.090000  1.40  13.000000  3.52  2.13
# 2006-11-17  19.060009  33.000000  16.150000  1.40  12.940000  3.59  2.12
# 2006-12-20  9.50  9.00  15.69  33.110001  19.949999  16.110001  17.110001
# 2006-12-19  9.55  8.94  15.08  33.080000  19.849997  16.190001  17.250000
# 2006-12-18  9.67  8.93  14.85  33.540001  20.749994  16.650000  17.690001
# 2006-12-15  9.68  8.99  15.80  34.010001  20.150002  16.719999  17.900000
#
#              ACTA       ACXM      ADMP       ADBE
# Date
# 2006-12-21  10.11  25.770000  0.059996  42.040001
# 2006-12-20   9.94  25.629999  0.059996  42.439999
# 2006-12-19   9.78  25.629999  0.059996  41.549999
# 2006-12-18   9.75  25.809999  0.059996  42.549999
# 2006-12-15   9.71  25.889999  0.069996  43.220001

# %%
# For the purposes of labeling/analysis, TRANSPOSE() the data frame.
df_long = df.transpose()
# Create a temporary'Symbol' column (necessary later for merging Sector types)
df_long['Symbol'] = df_long.index

# %%
# This is what it looks like.
df_long.head()
# Out:
# Date  2016-12-30 00:00:00  2016-12-29 00:00:00  2016-12-28 00:00:00  \
# FCCY            19.000000            20.850000            18.500000
# SRCE            45.610001            45.520000            45.070000
# JOBS            33.980000            33.980000            33.889999
# ABEO             4.950000             5.150000             5.440000
# ABMD           113.989998           114.360001           114.300003
#
# Date  2016-12-27 00:00:00  2016-12-23 00:00:00  2016-12-22 00:00:00  \
# FCCY            18.250000            17.350000            17.350000
# SRCE            44.860001            44.750000            44.840000
# JOBS            33.750000            33.410000            33.150002
# ABEO             5.350000             4.800000             4.950000
# ABMD           113.949997           113.080002           113.300003
#
# Date  2016-12-21 00:00:00  2016-12-20 00:00:00  2016-12-19 00:00:00  \
# FCCY            17.950001            17.920000            17.500000
# SRCE            45.099998            45.029999            44.270000
# JOBS            33.290001            32.910000            33.369999
# ABEO             4.430000             4.600000             4.750000
# ABMD           114.730003           117.690002           118.360001
#
# Date  2016-12-16 00:00:00 Symbol
# FCCY            17.299999   FCCY
# SRCE            44.110001   SRCE
# JOBS            33.580002   JOBS
# ABEO             4.950000   ABEO
# ABMD           119.440002   ABMD

# %%
final = newcsv.reset_index()

# %%
# Using pd.merge() to add a column for Sector to each row of our main data frame:
sector  = final[['Symbol','Sector']]

# %%
# matching Symbols to Sector:
final = pd.merge(df_long, sector, on = 'Symbol')
final.head()
# Out:
# Date  2016-12-30 00:00:00  2016-12-29 00:00:00  2016-12-28 00:00:00  \
# 0               19.000000            20.850000            18.500000
# 1               45.610001            45.520000            45.070000
# 2               33.980000            33.980000            33.889999
# 3                4.950000             5.150000             5.440000
# 4              113.989998           114.360001           114.300003
#
# Date  2016-12-27 00:00:00  2016-12-23 00:00:00  2016-12-22 00:00:00  \
# 0               18.250000            17.350000            17.350000
# 1               44.860001            44.750000            44.840000
# 2               33.750000            33.410000            33.150002
# 3                5.350000             4.800000             4.950000
# 4              113.949997           113.080002           113.300003
#
# Date  2016-12-21 00:00:00  2016-12-20 00:00:00  2016-12-19 00:00:00  \
# 0               17.950001            17.920000            17.500000
# 1               45.099998            45.029999            44.270000
# 2               33.290001            32.910000            33.369999
# 3                4.430000             4.600000             4.750000
# 4              114.730003           117.690002           118.360001
#
# Date  2016-12-16 00:00:00 Symbol       Sector
# 0               17.299999   FCCY      Finance
# 1               44.110001   SRCE      Finance
# 2               33.580002   JOBS   Technology
# 3                4.950000   ABEO  Health Care
# 4              119.440002   ABMD  Health Care

# %%
# Playing around with sample subset data to see how plotting will work.
# Will need to convert column headers to datetime to implement timeseries plot 
# Bc not sure if standard line plot will work if we want to use ARMA models
# or forecasting later on.
#
# Let's try this?
# http://www.blackarbs.com/blog/advanced-time-series-plots-in-python/1/6/2017

# take average within groups for each recorded date:
avg_sector = final.groupby('Sector').mean().reset_index()
avg_sector = avg_sector.set_index('Sector')
avg_sector
# Out:
# Date         2016-12-30 00:00:00  2016-12-29 00:00:00  2016-12-28 00:00:00  \
# Sector
# Energy                  2.640000             2.650000             2.670000
# Finance                30.990000            31.650000            31.135000
# Health Care            28.891250            28.980000            28.916250
# Technology             39.073334            39.198333            39.396667
#
# Date         2016-12-27 00:00:00  2016-12-23 00:00:00  2016-12-22 00:00:00  \
# Sector
# Energy                  2.680000               2.6200             2.690000
# Finance                31.067501              30.7450            30.897500
# Health Care            29.220000              28.8075            28.623750
# Technology             39.531667              39.2100            39.161667
#
# Date         2016-12-21 00:00:00  2016-12-20 00:00:00  2016-12-19 00:00:00  \
# Sector
# Energy                  2.700000               2.6200              2.64000
# Finance                31.057500              31.0575             30.69750
# Health Care            28.761251              29.4200             29.31875
# Technology             39.466667              39.4950             39.51500
#
# Date         2016-12-16 00:00:00
# Sector
# Energy                  2.590000
# Finance                30.585000
# Health Care            29.635000
# Technology             39.886667

# %%
# (UN-USED)
# separate data frames for each sector
eng = avg_sector[avg_sector['Sector'] == 'Energy']
fin = avg_sector[avg_sector['Sector'] == 'Finance']
health = avg_sector[avg_sector['Sector'] == 'Health Care']
tech = avg_sector[avg_sector['Sector'] == 'Technology']

# %%
# Dates as index for plotting
# This is basically the original DF (transposed and transposed back)
# but the columns are now the Sector averages.
avg_T = avg_sector.transpose()
avg_T.head()
# Out:
# Sector               Energy    Finance  Health Care  Technology
# Date
# 2016-12-30 00:00:00    2.64  30.990000     28.89125   39.073334
# 2016-12-29 00:00:00    2.65  31.650000     28.98000   39.198333
# 2016-12-28 00:00:00    2.67  31.135000     28.91625   39.396667
# 2016-12-27 00:00:00    2.68  31.067501     29.22000   39.531667
# 2016-12-23 00:00:00    2.62  30.745000     28.80750   39.210000

# %% [markdown]
# #### ```avg_T``` is the Data Frame we use for Time Series plotting in ```matplotlib```.

# %%
# A new DF for the difference between each day:
delta_df = pd.DataFrame()
for sect in avg_T.columns:
    delta_df[sect] = avg_T[sect] - avg_T[sect].shift(1) 
delta_df.columns = map(lambda name: '{} Changes'.format(name),avg_T.columns)
delta_df
# Out:
#             Energy Changes  Finance Changes  Health Care Changes  \
# 2016-12-30             NaN              NaN                  NaN
# 2016-12-29            0.01     6.600000e-01             0.088750
# 2016-12-28            0.02    -5.150000e-01            -0.063749
# 2016-12-27            0.01    -6.749900e-02             0.303750
# 2016-12-23           -0.06    -3.225010e-01            -0.412500
# 2016-12-22            0.07     1.525002e-01            -0.183750
# 2016-12-21            0.01     1.599997e-01             0.137500
# 2016-12-20           -0.08     2.500000e-07             0.658749
# 2016-12-19            0.02    -3.599998e-01            -0.101250
# 2016-12-16           -0.05    -1.125003e-01             0.316251
#
#             Technology Changes
# 2016-12-30                 NaN
# 2016-12-29            0.124999
# 2016-12-28            0.198335
# 2016-12-27            0.135000
# 2016-12-23           -0.321667
# 2016-12-22           -0.048333
# 2016-12-21            0.305000
# 2016-12-20            0.028333
# 2016-12-19            0.020000
# 2016-12-16            0.371667

# %%
# On what day did the stock price spike the most?
abs(delta_df).idxmax()
# Out:
# Energy Changes        2016-12-20
# Finance Changes       2016-12-29
# Health Care Changes   2016-12-20
# Technology Changes    2016-12-16
# dtype: datetime64[ns]

# %%
# Figure out what happened on these days...
# Still trying to figure out how to do this part, but it would be cool to use an API or webscrape a news site.
# Worst-Case scenario: We manually find events and plot them.

# %%
# Making Plots
plot_cols = list(avg_T.columns)

# 2 axes for 2 subplots
fig, axes = plt.subplots(4,1, figsize=(10,7), sharex=True)
avg_clean[plot_cols].plot(subplots=True, ax=axes)
plt.show()

# %% [markdown]
# #### In Progress: Adding an interactive "timeline" below these plots with major events
#
# Resources:
# http://stackoverflow.com/questions/32619424/is-it-possible-to-plot-timelines-with-matplotlib
# http://mpld3.github.io/notebooks/custom_plugins.html

# %%
# how to create an interactive timeline
import mpld3
mpld3.enable_notebook()    # this is required to make plot interactive,
                            # but it messes with ALL the other plots on the notebook.
                            # USE disable_notebook()   to change back.

fig, ax = plt.subplots()
points = ax.scatter(np.random.rand(40), np.random.rand(40),
                    s=300, alpha=0.3)
# labels: list of string objects
labels = ["Point {0}".format(i) for i in range(40)]
tooltip = plugins.PointLabelTooltip(points, labels)

plugins.connect(fig, tooltip)

# %%
# This is our attempt at creating an interactive "TIMELINE"
# we cannot figure out how to erase y-axis
datelist = pd.date_range(pd.to_datetime('2016-11-1'),periods=60).tolist()
eventlist = [pd.to_datetime('2016-11-8'),pd.to_datetime('2016-12-25')]
labels = ['e1','e2']
fig, ax = plt.subplots(figsize=(15,5))
points = ax.scatter(eventlist, [1]*len(eventlist),
           marker='s', s=100)
fig.autofmt_xdate()
ax.set_xlim([pd.to_datetime('2016-11-1'), pd.to_datetime('2016-12-31')])
ax.set_ylim(0.9999999,1.0000001)
tooltip = plugins.PointLabelTooltip(points, labels)

plugins.connect(fig, tooltip)

# %%
### can i delete this stuff below?

# %%
prices = avg_sector.iloc[:,1:11]

# %%
prices
# Out:
# Date  2016-12-30 00:00:00  2016-12-29 00:00:00  2016-12-28 00:00:00  \
# 0                2.640000             2.650000             2.670000
# 1               30.990000            31.650000            31.135000
# 2               28.891250            28.980000            28.916250
# 3               39.073334            39.198333            39.396667
#
# Date  2016-12-27 00:00:00  2016-12-23 00:00:00  2016-12-22 00:00:00  \
# 0                2.680000               2.6200             2.690000
# 1               31.067501              30.7450            30.897500
# 2               29.220000              28.8075            28.623750
# 3               39.531667              39.2100            39.161667
#
# Date  2016-12-21 00:00:00  2016-12-20 00:00:00  2016-12-19 00:00:00  \
# 0                2.700000               2.6200              2.64000
# 1               31.057500              31.0575             30.69750
# 2               28.761251              29.4200             29.31875
# 3               39.466667              39.4950             39.51500
#
# Date  2016-12-16 00:00:00
# 0                2.590000
# 1               30.585000
# 2               29.635000
# 3               39.886667

# %%
date = list(prices.columns.values)

# %%
dates = [pd.to_datetime(date[x]) for x in range(0,len(date))]
dates
# Out:
# [Timestamp('2001-01-12 00:00:00'),
#  Timestamp('2001-01-16 00:00:00'),
#  Timestamp('2001-01-17 00:00:00'),
#  Timestamp('2001-01-18 00:00:00'),
#  Timestamp('2001-01-19 00:00:00'),
#  Timestamp('2001-01-22 00:00:00'),
#  Timestamp('2001-01-23 00:00:00'),
#  Timestamp('2001-01-24 00:00:00'),
#  Timestamp('2001-01-25 00:00:00'),
#  Timestamp('2001-01-26 00:00:00')]

# %%
# data[plot_cols].plot(subplots=True, ax=axes)
# Out:
# datetime.datetime(2005, 6, 1, 13, 33)

# %%
# yhoo= myget(10, 'TWOU')
# yhoo
# tr = Share('VNET')
# try:
#    tr.get_historical('2000-11-03', '2001-01-28')
# except Exception:
#    pass

# %%
comp = Share('YHOO')

# %%
report = []

c = comp.get_historical('2000-11-03', '2001-01-28')
        
for i in range(0,10):
    dat = {'Symbol':c[i]['Symbol'],c[i]['Date']:float(c[i]['High']),'Sector':c[i]['Sector']} 
    report.append(dat)
    df = pd.DataFrame(report)
    df = df.replace(np.nan, 0).groupby('Symbol').sum()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-93-c935b63e5b10> in <module>()
#       4
#       5 for i in range(0,10):
# ----> 6     dat = {'Symbol':c[i]['Symbol'],c[i]['Date']:float(c[i]['High']),'Sector':c[i]['Sector']}
#       7     report.append(dat)
#       8     df = pd.DataFrame(report)
#
# KeyError: 'Sector'

# %%
comp.get_historical('2000-11-03', '2001-01-28')
# Out:
# [{'Adj_Close': '18.84375',
#   'Close': '37.6875',
#   'Date': '2001-01-26',
#   'High': '38.625',
#   'Low': '36.125',
#   'Open': '37.625',
#   'Symbol': 'YHOO',
#   'Volume': '24462600'},
#  {'Adj_Close': '19.59375',
#   'Close': '39.1875',
#   'Date': '2001-01-25',
#   'High': '42.8125',
#   'Low': '38.5625',
#   'Open': '41.875',
#   'Symbol': 'YHOO',
#   'Volume': '44249200'},
#  {'Adj_Close': '21.4375',
#   'Close': '42.875',
#   'Date': '2001-01-24',
#   'High': '43.375',
#   'Low': '38.00',
#   'Open': '38.3125',
#   'Symbol': 'YHOO',
#   'Volume': '57294800'},
#  {'Adj_Close': '19.476549',
#   'Close': '38.953098',
#   'Date': '2001-01-23',
#   'High': '39.00',
#   'Low': '34.1875',
#   'Open': '34.4375',
#   'Symbol': 'YHOO',
#   'Volume': '34783200'},
#  {'Adj_Close': '17.34375',
#   'Close': '34.6875',
#   'Date': '2001-01-22',
#   'High': '35.75',
#   'Low': '32.5625',
#   'Open': '33.3125',
#   'Symbol': 'YHOO',
#   'Volume': '25512600'},
#  {'Adj_Close': '16.90625',
#   'Close': '33.8125',
#   'Date': '2001-01-19',
#   'High': '36.0625',
#   'Low': '32.5625',
#   'Open': '36.00',
#   'Symbol': 'YHOO',
#   'Volume': '40979800'},
#  {'Adj_Close': '17.21875',
#   'Close': '34.4375',
#   'Date': '2001-01-18',
#   'High': '34.75',
#   'Low': '29.6875',
#   'Open': '31.00',
#   'Symbol': 'YHOO',
#   'Volume': '57925400'},
#  {'Adj_Close': '15.125',
#   'Close': '30.25',
#   'Date': '2001-01-17',
#   'High': '31.75',
#   'Low': '27.9375',
#   'Open': '28.625',
#   'Symbol': 'YHOO',
#   'Volume': '66939000'},
#  {'Adj_Close': '13.6875',
#   'Close': '27.375',
#   'Date': '2001-01-16',
#   'High': '28.4375',
#   'Low': '26.625',
#   'Open': '27.00',
#   'Symbol': 'YHOO',
#   'Volume': '32059000'},
#  {'Adj_Close': '13.28125',
#   'Close': '26.5625',
#   'Date': '2001-01-12',
#   'High': '26.875',
#   'Low': '25.0625',
#   'Open': '26.0625',
#   'Symbol': 'YHOO',
#   'Volume': '50575600'},
#  {'Adj_Close': '12.9375',
#   'Close': '25.875',
#   'Date': '2001-01-11',
#   'High': '26.625',
#   'Low': '24.125',
#   'Open': '24.421801',
#   'Symbol': 'YHOO',
#   'Volume': '132926800'},
#  {'Adj_Close': '15.25',
#   'Close': '30.50',
#   'Date': '2001-01-10',
#   'High': '31.25',
#   'Low': '27.875',
#   'Open': '29.3125',
#   'Symbol': 'YHOO',
#   'Volume': '54304200'},
#  {'Adj_Close': '15.0625',
#   'Close': '30.125',
#   'Date': '2001-01-09',
#   'High': '30.5625',
#   'Low': '26.00',
#   'Open': '26.5625',
#   'Symbol': 'YHOO',
#   'Volume': '43097200'},
#  {'Adj_Close': '13.59375',
#   'Close': '27.1875',
#   'Date': '2001-01-08',
#   'High': '27.50',
#   'Low': '25.375',
#   'Open': '27.375',
#   'Symbol': 'YHOO',
#   'Volume': '26165200'},
#  {'Adj_Close': '14.25',
#   'Close': '28.50',
#   'Date': '2001-01-05',
#   'High': '31.375',
#   'Low': '27.875',
#   'Open': '29.375',
#   'Symbol': 'YHOO',
#   'Volume': '26867400'},
#  {'Adj_Close': '14.78125',
#   'Close': '29.5625',
#   'Date': '2001-01-04',
#   'High': '32.1875',
#   'Low': '29.4375',
#   'Open': '29.859301',
#   'Symbol': 'YHOO',
#   'Volume': '35051800'},
#  {'Adj_Close': '15.46875',
#   'Close': '30.9375',
#   'Date': '2001-01-03',
#   'High': '32.5625',
#   'Low': '25.984301',
#   'Open': '27.75',
#   'Symbol': 'YHOO',
#   'Volume': '49936600'},
#  {'Adj_Close': '14.09375',
#   'Close': '28.1875',
#   'Date': '2001-01-02',
#   'High': '30.375',
#   'Low': '27.50',
#   'Open': '30.3125',
#   'Symbol': 'YHOO',
#   'Volume': '21939200'},
#  {'Adj_Close': '15.03125',
#   'Close': '30.0625',
#   'Date': '2000-12-29',
#   'High': '31.1875',
#   'Low': '29.5625',
#   'Open': '30.3125',
#   'Symbol': 'YHOO',
#   'Volume': '20893400'},
#  {'Adj_Close': '15.50',
#   'Close': '31.00',
#   'Date': '2000-12-28',
#   'High': '31.75',
#   'Low': '29.125',
#   'Open': '29.4375',
#   'Symbol': 'YHOO',
#   'Volume': '24374600'},
#  {'Adj_Close': '14.875',
#   'Close': '29.75',
#   'Date': '2000-12-27',
#   'High': '31.50',
#   'Low': '29.125',
#   'Open': '31.00',
#   'Symbol': 'YHOO',
#   'Volume': '22045400'},
#  {'Adj_Close': '15.59375',
#   'Close': '31.1875',
#   'Date': '2000-12-26',
#   'High': '34.00',
#   'Low': '30.125',
#   'Open': '32.00',
#   'Symbol': 'YHOO',
#   'Volume': '37536200'},
#  {'Adj_Close': '14.78125',
#   'Close': '29.5625',
#   'Date': '2000-12-22',
#   'High': '29.875',
#   'Low': '26.0625',
#   'Open': '26.4375',
#   'Symbol': 'YHOO',
#   'Volume': '28347400'},
#  {'Adj_Close': '12.8125',
#   'Close': '25.625',
#   'Date': '2000-12-21',
#   'High': '28.25',
#   'Low': '25.0625',
#   'Open': '26.75',
#   'Symbol': 'YHOO',
#   'Volume': '27794400'},
#  {'Adj_Close': '13.96875',
#   'Close': '27.9375',
#   'Date': '2000-12-20',
#   'High': '28.375',
#   'Low': '25.50',
#   'Open': '25.8125',
#   'Symbol': 'YHOO',
#   'Volume': '44862800'},
#  {'Adj_Close': '14.00',
#   'Close': '28.00',
#   'Date': '2000-12-19',
#   'High': '31.9687',
#   'Low': '28.00',
#   'Open': '30.5625',
#   'Symbol': 'YHOO',
#   'Volume': '36131600'},
#  {'Adj_Close': '16.00',
#   'Close': '32.00',
#   'Date': '2000-12-18',
#   'High': '34.00',
#   'Low': '30.25',
#   'Open': '33.875',
#   'Symbol': 'YHOO',
#   'Volume': '31697600'},
#  {'Adj_Close': '16.50',
#   'Close': '33.00',
#   'Date': '2000-12-15',
#   'High': '34.00',
#   'Low': '31.0625',
#   'Open': '32.00',
#   'Symbol': 'YHOO',
#   'Volume': '40448000'},
#  {'Adj_Close': '16.00',
#   'Close': '32.00',
#   'Date': '2000-12-14',
#   'High': '35.9062',
#   'Low': '31.9375',
#   'Open': '35.3125',
#   'Symbol': 'YHOO',
#   'Volume': '20899800'},
#  {'Adj_Close': '17.4375',
#   'Close': '34.875',
#   'Date': '2000-12-13',
#   'High': '38.625',
#   'Low': '34.25',
#   'Open': '38.3125',
#   'Symbol': 'YHOO',
#   'Volume': '33640400'},
#  {'Adj_Close': '17.90625',
#   'Close': '35.8125',
#   'Date': '2000-12-12',
#   'High': '39.50',
#   'Low': '32.9375',
#   'Open': '33.25',
#   'Symbol': 'YHOO',
#   'Volume': '79275800'},
#  {'Adj_Close': '16.9375',
#   'Close': '33.875',
#   'Date': '2000-12-11',
#   'High': '37.0625',
#   'Low': '30.625',
#   'Open': '33.625',
#   'Symbol': 'YHOO',
#   'Volume': '71038800'},
#  {'Adj_Close': '17.46875',
#   'Close': '34.9375',
#   'Date': '2000-12-08',
#   'High': '37.125',
#   'Low': '32.125',
#   'Open': '37.125',
#   'Symbol': 'YHOO',
#   'Volume': '49184000'},
#  {'Adj_Close': '17.46875',
#   'Close': '34.9375',
#   'Date': '2000-12-07',
#   'High': '36.2187',
#   'Low': '31.50',
#   'Open': '36.0625',
#   'Symbol': 'YHOO',
#   'Volume': '55136200'},
#  {'Adj_Close': '18.75',
#   'Close': '37.50',
#   'Date': '2000-12-06',
#   'High': '42.9375',
#   'Low': '37.125',
#   'Open': '41.625',
#   'Symbol': 'YHOO',
#   'Volume': '32559800'},
#  {'Adj_Close': '21.9375',
#   'Close': '43.875',
#   'Date': '2000-12-05',
#   'High': '44.00',
#   'Low': '39.3125',
#   'Open': '39.6875',
#   'Symbol': 'YHOO',
#   'Volume': '30714800'},
#  {'Adj_Close': '18.96875',
#   'Close': '37.9375',
#   'Date': '2000-12-04',
#   'High': '39.3125',
#   'Low': '36.1875',
#   'Open': '38.4375',
#   'Symbol': 'YHOO',
#   'Volume': '29997600'},
#  {'Adj_Close': '19.46875',
#   'Close': '38.9375',
#   'Date': '2000-12-01',
#   'High': '41.125',
#   'Low': '36.375',
#   'Open': '38.8125',
#   'Symbol': 'YHOO',
#   'Volume': '40172600'},
#  {'Adj_Close': '19.8125',
#   'Close': '39.625',
#   'Date': '2000-11-30',
#   'High': '39.625',
#   'Low': '35.1875',
#   'Open': '37.5937',
#   'Symbol': 'YHOO',
#   'Volume': '33938200'},
#  {'Adj_Close': '19.53125',
#   'Close': '39.0625',
#   'Date': '2000-11-29',
#   'High': '39.25',
#   'Low': '35.6875',
#   'Open': '37.140598',
#   'Symbol': 'YHOO',
#   'Volume': '35039400'},
#  {'Adj_Close': '18.48435',
#   'Close': '36.9687',
#   'Date': '2000-11-28',
#   'High': '40.50',
#   'Low': '35.75',
#   'Open': '39.9375',
#   'Symbol': 'YHOO',
#   'Volume': '29390800'},
#  {'Adj_Close': '20.0625',
#   'Close': '40.125',
#   'Date': '2000-11-27',
#   'High': '45.00',
#   'Low': '40.00',
#   'Open': '43.734299',
#   'Symbol': 'YHOO',
#   'Volume': '24838400'},
#  {'Adj_Close': '20.4375',
#   'Close': '40.875',
#   'Date': '2000-11-24',
#   'High': '42.25',
#   'Low': '39.375',
#   'Open': '40.25',
#   'Symbol': 'YHOO',
#   'Volume': '19702400'},
#  {'Adj_Close': '19.09375',
#   'Close': '38.1875',
#   'Date': '2000-11-22',
#   'High': '43.00',
#   'Low': '38.0625',
#   'Open': '40.375',
#   'Symbol': 'YHOO',
#   'Volume': '43183200'},
#  {'Adj_Close': '20.84375',
#   'Close': '41.6875',
#   'Date': '2000-11-21',
#   'High': '48.00',
#   'Low': '40.5625',
#   'Open': '47.00',
#   'Symbol': 'YHOO',
#   'Volume': '49950200'},
#  {'Adj_Close': '24.4375',
#   'Close': '48.875',
#   'Date': '2000-11-20',
#   'High': '51.375',
#   'Low': '47.875',
#   'Open': '50.375',
#   'Symbol': 'YHOO',
#   'Volume': '18448400'},
#  {'Adj_Close': '25.625',
#   'Close': '51.25',
#   'Date': '2000-11-17',
#   'High': '55.50',
#   'Low': '50.00',
#   'Open': '52.203098',
#   'Symbol': 'YHOO',
#   'Volume': '21516400'},
#  {'Adj_Close': '26.46875',
#   'Close': '52.9375',
#   'Date': '2000-11-16',
#   'High': '56.50',
#   'Low': '52.625',
#   'Open': '55.00',
#   'Symbol': 'YHOO',
#   'Volume': '13573000'},
#  {'Adj_Close': '28.5625',
#   'Close': '57.125',
#   'Date': '2000-11-15',
#   'High': '60.00',
#   'Low': '54.75',
#   'Open': '58.25',
#   'Symbol': 'YHOO',
#   'Volume': '16191200'},
#  {'Adj_Close': '29.71875',
#   'Close': '59.4375',
#   'Date': '2000-11-14',
#   'High': '59.50',
#   'Low': '55.50',
#   'Open': '57.6875',
#   'Symbol': 'YHOO',
#   'Volume': '13959400'},
#  {'Adj_Close': '27.65625',
#   'Close': '55.3125',
#   'Date': '2000-11-13',
#   'High': '59.125',
#   'Low': '52.00',
#   'Open': '54.8125',
#   'Symbol': 'YHOO',
#   'Volume': '19343200'},
#  {'Adj_Close': '28.21875',
#   'Close': '56.4375',
#   'Date': '2000-11-10',
#   'High': '61.75',
#   'Low': '56.125',
#   'Open': '57.8125',
#   'Symbol': 'YHOO',
#   'Volume': '19196200'},
#  {'Adj_Close': '29.40625',
#   'Close': '58.8125',
#   'Date': '2000-11-09',
#   'High': '62.875',
#   'Low': '56.50',
#   'Open': '60.859299',
#   'Symbol': 'YHOO',
#   'Volume': '26721000'},
#  {'Adj_Close': '32.50',
#   'Close': '65.00',
#   'Date': '2000-11-08',
#   'High': '70.625',
#   'Low': '64.9375',
#   'Open': '69.25',
#   'Symbol': 'YHOO',
#   'Volume': '16011400'},
#  {'Adj_Close': '34.25',
#   'Close': '68.50',
#   'Date': '2000-11-07',
#   'High': '69.125',
#   'Low': '63.625',
#   'Open': '65.9375',
#   'Symbol': 'YHOO',
#   'Volume': '13889800'},
#  {'Adj_Close': '32.8125',
#   'Close': '65.625',
#   'Date': '2000-11-06',
#   'High': '70.4375',
#   'Low': '65.375',
#   'Open': '70.25',
#   'Symbol': 'YHOO',
#   'Volume': '14251200'},
#  {'Adj_Close': '34.375',
#   'Close': '68.75',
#   'Date': '2000-11-03',
#   'High': '70.5625',
#   'Low': '66.625',
#   'Open': '69.375',
#   'Symbol': 'YHOO',
#   'Volume': '20381800'}]
